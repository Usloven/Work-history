# %%
import os
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
file = r"C:\Users\aleksandrov.vd\Documents\Передвижки\Передвижка 22\2022\Исходник.xlsx"
df =  pd.read_excel(file, index_col=0)

# %%
df = df.reset_index() 
df
# Out:
#               index         Unnamed: 1         Unnamed: 2  \
# 0               NaN                NaN                NaN
# 1    Названия строк  Сумма по полю SO2  Сумма по полю NOx
# 2                17                 12                 10
# 3                18                 12                 10
# 4                 4                 12                 10
# ..              ...                ...                ...
# 544              N3           0.237688           6.184974
# 545         (пусто)          37.486958         908.568489
# 546         (пусто)          37.486958         908.568489
# 547         (пусто)          37.486958         908.568489
# 548      Общий итог          86.973915        1827.136979
#
#               Unnamed: 3        Unnamed: 4       Unnamed: 5  \
# 0                    NaN               NaN              NaN
# 1    Сумма по полю ЛОСНМ  Сумма по полю CO  Сумма по полю C
# 2                     14                 9               11
# ...

# %%
df.columns
# Out:
# Index(['Код объекта НВОС', 'ИНН организации', 'Субъект РФ (id)',
#        'Состоит на учете (id)', 'Контролирующий орган объекта НВОС (id)',
#        'Категория объекта НВОС (id)', 'Категория объекта НВОС', 'Код ОКТМО',
#        'Код ОКТМО (название)', 'Наименование объекта НВОС', 'Тип реестра (id)',
#        'Адрес объекта НВОС', 'Код ОКВЭД (детальный)',
#        'Наименование организации', 'КПП организации', 'ОГРН организации',
#        'Орган, выдавший свидетельство объекту (id)',
#        'Орган, выдавший свидетельство', 'Состоит на учете', 'Субъект РФ',
#        'Кол-во  источников выбросов', 'Суммарный выброс, т/год',
#        'Кол-во объектов размещения отходов', 'Суммарная масса отходов, т/год',
#        'Выбросы парниковых газов (СО2), т/год'],
#       dtype='object')

# %%
df.describe()
# Out:
#        Субъект РФ (id)  Состоит на учете (id)  \
# count    471576.000000          471576.000000
# mean         60.472365             161.225187
# std         102.823269             158.596934
# min           1.000000               1.000000
# 25%          20.000000              21.000000
# 50%          45.000000             229.000000
# 75%          71.000000             266.000000
# max         719.000000            1034.000000
#
#        Контролирующий орган объекта НВОС (id)  Категория объекта НВОС (id)  \
# count                           471576.000000                471522.000000
# mean                               160.239768                     3.266022
# std                                158.655087                     0.703896
# min                                  1.000000                     1.000000
# 25%                                 21.000000                     3.000000
# 50%                                229.000000                     3.000000
# ...

# %%
df = df.sort_values(by = "Суммарный выброс, т/год", ascending=False)
df
# Out:
#         Код объекта НВОС ИНН организации  Субъект РФ (id)  \
# 20784   12-0230-006902-П      7703030058               12
# 432567  17-0133-000644-П      3304009593               17
# 344969  03-0123-008682-П      2328000083                3
# 340907  47-0151-000455-П      5192110268               47
# 319940  03-0123-007353-П      2328000083                3
# ...                  ...             ...              ...
# 471541  07-0126-003865-П      2310031475                7
# 471547  98-0114-002907-П      1433015633               98
# 471549  46-0167-004731-П      7728168971               46
# 471560  36-0263-010042-П      6330073544               36
# 471567  46-0167-004729-П      7728168971               46
#
#         Состоит на учете (id)  Контролирующий орган объекта НВОС (id)  \
# 20784                      29                                      29
# 432567                     25                                      25
# ...

# %%
# df["Суммарный выброс, т/год"].plot(kind="density", figsize=(9,9));
df["Логарифм"] = np.log1p(df["Суммарный выброс, т/год"])
df["Суммарный выброс, т/год"].hist(bins=100);
# Out:
# C:\Users\aleksandrov.vd\AppData\Local\anaconda3\lib\site-packages\pandas\core\arraylike.py:402: RuntimeWarning: invalid value encountered in log1p
#   result = getattr(ufunc, method)(*inputs, **kwargs)

# %%
import matplotlib.mlab as mlab
import matplotlib
plt.style.use('ggplot')
from matplotlib.pyplot import figure

matplotlib.rcParams['figure.figsize'] = (12,8)

pd.options.mode.chained_assignment = None



# чтение данных


# shape and data types of the data
print(df.shape)
print(df.dtypes)

# отбор числовых колонок
df_numeric = df.select_dtypes(include=[np.number])
numeric_cols = df_numeric.columns.values
print(numeric_cols)

# отбор нечисловых колонок
df_non_numeric = df.select_dtypes(exclude=[np.number])
non_numeric_cols = df_non_numeric.columns.values
print(non_numeric_cols)
# Out:
# (471576, 26)
# Код объекта НВОС                               object
# ИНН организации                                object
# Субъект РФ (id)                                 int64
# Состоит на учете (id)                           int64
# Контролирующий орган объекта НВОС (id)          int64
# Категория объекта НВОС (id)                   float64
# Категория объекта НВОС                        float64
# Код ОКТМО                                     float64
# Код ОКТМО (название)                           object
# Наименование объекта НВОС                      object
# Тип реестра (id)                              float64
# Адрес объекта НВОС                             object
# Код ОКВЭД (детальный)                          object
# Наименование организации                       object
# КПП организации                                object
# ОГРН организации                               object
# Орган, выдавший свидетельство объекту (id)      int64
# ...

# %%
df.boxplot(column=["Суммарный выброс, т/год"])
# Out:
# <Axes: >

# %%
df["Суммарный выброс, т/год"].describe()
# Out:
# count    3.895000e+05
# mean     1.127487e+07
# std      4.998833e+09
# min     -2.695119e+00
# 25%      5.690000e-02
# 50%      4.403037e-01
# 75%      3.624000e+00
# max      3.001957e+12
# Name: Суммарный выброс, т/год, dtype: float64

# %%
import seaborn as sns
sns.distplot(df["Выбросы парниковых газов (СО2), т/год"].dropna())
# Out:
# C:\Users\aleksandrov.vd\AppData\Local\Temp\ipykernel_11508\792576169.py:2: UserWarning:
#
# `distplot` is a deprecated function and will be removed in seaborn v0.14.0.
#
# Please adapt your code to use either `displot` (a figure-level function with
# similar flexibility) or `histplot` (an axes-level function for histograms).
#
# For a guide to updating your code to use the new functions, please see
# https://gist.github.com/mwaskom/de44147ed2974457ad6372750bbe5751
#
#   sns.distplot(df["Выбросы парниковых газов (СО2), т/год"].dropna())
# <Axes: xlabel='Выбросы парниковых газов (СО2), т/год', ylabel='Density'>

# %%
df1 = df.dropna()

# %%
df1.boxplot(column=["Выбросы парниковых газов (СО2), т/год"])
# Out:
# <Axes: >

# %%
df1.boxplot(column=["Кол-во  источников выбросов"])
# Out:
# <Axes: >

# %%
z = np.abs(stats.zscore(df['column_name']))

#only keep rows in dataframe with all z-scores less than absolute value of 3 
data_clean = df['column_name'][(z<3).all(axis=1)]

#find how many rows are left in the dataframe 
data_clean.head()
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[14], line 1
# ----> 1 z = np.abs(stats.zscore(df['column_name']))
#       3 #only keep rows in dataframe with all z-scores less than absolute value of 3
#       4 data_clean = df['column_name'][(z<3).all(axis=1)]
#
# NameError: name 'stats' is not defined
